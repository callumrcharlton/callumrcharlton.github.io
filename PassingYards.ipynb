# %%
import pandas as pd

# %% [markdown]
# https://en.wikipedia.org/wiki/List_of_National_Football_League_career_passing_yards_leaders

# %%
wikilist = pd.read_html('https://en.wikipedia.org/wiki/List_of_National_Football_League_career_passing_yards_leaders')

# %%
s='Tom Brady*'

# %%
s.split('*')[0]
# Out:
# 'Tom Brady'

# %%
s.replace('*','').replace('^','')
# Out:
# 'Tom Brady'

# %%
mylist = wikilist[2]

# %%
alist = mylist.rename(columns={'.mw-parser-output .tooltip-dotted{border-bottom:1px dotted;cursor:help}Yards':'Yards'})

# %%
alist
# Out:
#     Rank              Player  \
# 0      1          Tom Brady*
# 1      2          Drew Brees
# 2      3     Peyton Manning^
# 3      4        Brett Favre^
# 4      5  Ben Roethlisberger
# 5      6       Philip Rivers
# 6      7          Matt Ryan*
# 7      8         Dan Marino^
# 8      9      Aaron Rodgers*
# 9     10         Eli Manning
# 10    11   Matthew Stafford*
# 11    12         John Elway^
# 12    13        Warren Moon^
# 13    14     Fran Tarkenton^
# 14    15       Carson Palmer
# 15    16    Vinny Testaverde
# 16    17        Drew Bledsoe
# 17    18          Dan Fouts^
# 18    19         Joe Flacco*
# 19    20       Kerry Collins
# 20    21        Joe Montana^
# 21    22      Johnny Unitas^
# 22    23     Russell Wilson*
# 23    24          Dave Krieg
# 24    25      Boomer Esiason
# 25    26        Andy Dalton*
# 26    27      Donovan McNabb
# 27    28       Kirk Cousins*
# 28    29     Matt Hasselbeck
# 29    30          Alex Smith
# 30    31          Jim Kelly^
# ...

# %%
blist = alist.drop(['Team(s) by season','YPG','GP'], axis=1)

# %%
clist = blist['Player'].str.replace('*','').str.replace('^','')
# Out:
# <ipython-input-98-a3cdb11fc9d1>:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   clist = blist['Player'].str.replace('*','').str.replace('^','')

# %%
dlist = blist

# %%
dlist['Player'] = clist

# %%
dlist
# Out:
#     Rank              Player  Yards
# 0      1           Tom Brady  88417
# 1      2          Drew Brees  80358
# 2      3      Peyton Manning  71940
# 3      4         Brett Favre  71838
# 4      5  Ben Roethlisberger  64088
# 5      6       Philip Rivers  63440
# 6      7           Matt Ryan  62792
# 7      8          Dan Marino  61361
# 8      9       Aaron Rodgers  58453
# 9     10         Eli Manning  57023
# 10    11    Matthew Stafford  52082
# 11    12          John Elway  51475
# 12    13         Warren Moon  49325
# 13    14      Fran Tarkenton  47003
# 14    15       Carson Palmer  46247
# 15    16    Vinny Testaverde  46233
# 16    17        Drew Bledsoe  44611
# 17    18           Dan Fouts  43040
# 18    19          Joe Flacco  42171
# 19    20       Kerry Collins  40922
# 20    21         Joe Montana  40551
# 21    22       Johnny Unitas  40239
# 22    23      Russell Wilson  39864
# 23    24          Dave Krieg  38147
# 24    25      Boomer Esiason  37920
# ...

# %%
dlist.to_csv('PassingYards.csv')
